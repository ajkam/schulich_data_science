# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/rupaliwadhawan/Downloads/Group Project Data-SFD Data-Toronto Police (4).xlsx')

# %%
df
# Out:
#               X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0    -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1    -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2    -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3    -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4    -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# ...         ...        ...       ...             ...                     ...
# 5702 -79.362941  43.771764      5703  GO-20221038418  2022/06/02 04:00:00+00
# 5703 -79.402702  43.643920      5704  GO-20221362949  2022/07/17 04:00:00+00
# 5704 -79.196217  43.786621      5705   GO-2022336423  2022/02/21 05:00:00+00
# 5705 -79.443993  43.658083      5706  GO-20221765442  2022/09/11 04:00:00+00
# 5706 -79.369456  43.654519      5707   GO-2022783839  2022/04/27 04:00:00+00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5707 non-null   float64
#  1   Y                  5707 non-null   float64
#  2   OBJECTID           5707 non-null   int64
#  3   EVENT_UNIQUE_ID    5707 non-null   object
#  4   OCC_DATE           5707 non-null   object
#  5   OCC_YEAR           5707 non-null   int64
#  6   OCC_MONTH          5707 non-null   object
#  7   OCC_DOW            5707 non-null   object
#  8   OCC_DOY            5707 non-null   int64
#  9   OCC_DAY            5707 non-null   int64
#  10  OCC_HOUR           5707 non-null   int64
#  11  OCC_TIME_RANGE     5707 non-null   object
#  12  DIVISION           5707 non-null   object
#  13  DEATH              5707 non-null   int64
#  14  INJURIES           5707 non-null   int64
#  15  HOOD_158           5707 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# X                    0
# Y                    0
# OBJECTID             0
# EVENT_UNIQUE_ID      0
# OCC_DATE             0
# OCC_YEAR             0
# OCC_MONTH            0
# OCC_DOW              0
# OCC_DOY              0
# OCC_DAY              0
# OCC_HOUR             0
# OCC_TIME_RANGE       0
# DIVISION             0
# DEATH                0
# INJURIES             0
# HOOD_158             0
# NEIGHBOURHOOD_158    0
# HOOD_140             0
# NEIGHBOURHOOD_140    0
# LONG_WGS84           0
# LAT_WGS84            0
# dtype: int64

# %%
import seaborn as sns

# %%
import numpy as np

# %%
df.replace('NSA',np.nan,inplace=True)

# %%
df.head(12)
# Out:
#             X          Y  OBJECTID EVENT_UNIQUE_ID                OCC_DATE
# 0  -79.234955  43.781528         1   GO-2004397105  2004/05/15 04:00:00+00  \
# 1  -79.618218  43.733547         2   GO-2004600109  2004/07/26 04:00:00+00
# 2  -79.518759  43.769157         3   GO-2004311851  2004/05/14 04:00:00+00
# 3  -79.378870  43.660665         4   GO-2004736004  2004/12/19 05:00:00+00
# 4  -79.212435  43.812075         5   GO-2004303455  2004/04/12 04:00:00+00
# 5  -79.318704  43.759919         6   GO-2004213938  2004/03/14 05:00:00+00
# 6  -79.197132  43.796763         7   GO-2004149554  2004/01/19 05:00:00+00
# 7  -79.588530  43.738688         8   GO-2004646393  2004/09/08 04:00:00+00
# 8  -79.427371  43.638954         9   GO-2004764704  2004/04/14 04:00:00+00
# 9  -85.488744   0.000000        10   GO-2004683174  2004/10/15 04:00:00+00
# 10 -79.335299  43.762583        11   GO-2004619258  2004/10/27 04:00:00+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5707 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5707 non-null   float64
#  1   Y                  5707 non-null   float64
#  2   OBJECTID           5707 non-null   int64
#  3   EVENT_UNIQUE_ID    5707 non-null   object
#  4   OCC_DATE           5707 non-null   object
#  5   OCC_YEAR           5707 non-null   int64
#  6   OCC_MONTH          5707 non-null   object
#  7   OCC_DOW            5707 non-null   object
#  8   OCC_DOY            5707 non-null   int64
#  9   OCC_DAY            5707 non-null   int64
#  10  OCC_HOUR           5707 non-null   int64
#  11  OCC_TIME_RANGE     5707 non-null   object
#  12  DIVISION           5707 non-null   object
#  13  DEATH              5707 non-null   int64
#  14  INJURIES           5707 non-null   int64
#  15  HOOD_158           5643 non-null   float64
# ...

# %%
df.dropna(how='any',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5641 entries, 0 to 5706
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  5641 non-null   float64
#  1   Y                  5641 non-null   float64
#  2   OBJECTID           5641 non-null   int64
#  3   EVENT_UNIQUE_ID    5641 non-null   object
#  4   OCC_DATE           5641 non-null   object
#  5   OCC_YEAR           5641 non-null   int64
#  6   OCC_MONTH          5641 non-null   object
#  7   OCC_DOW            5641 non-null   object
#  8   OCC_DOY            5641 non-null   int64
#  9   OCC_DAY            5641 non-null   int64
#  10  OCC_HOUR           5641 non-null   int64
#  11  OCC_TIME_RANGE     5641 non-null   object
#  12  DIVISION           5641 non-null   object
#  13  DEATH              5641 non-null   int64
#  14  INJURIES           5641 non-null   int64
#  15  HOOD_158           5641 non-null   float64
# ...

# %%
sns.scatterplot(data=df_count_per_year, x='OCC_YEAR', y='count')
# Out:
# <Axes: xlabel='OCC_YEAR', ylabel='count'>

# %%
df_count_per_year = pd.DataFrame(df['OCC_YEAR'].value_counts())

# %%
nameplot = df['OCC_YEAR'].value_counts().plot.bar(figsize=(8,6))

# %%
df_groupby_year = df.groupby('OCC_YEAR').count()

# %%
df_groupby_year
# Out:
#             X    Y  OBJECTID  EVENT_UNIQUE_ID  OCC_DATE  OCC_MONTH  OCC_DOW
# OCC_YEAR
# 2004      183  183       183              183       183        183      183  \
# 2005      251  251       251              251       251        251      251
# 2006      208  208       208              208       208        208      208
# 2007      202  202       202              202       202        202      202
# 2008      235  235       235              235       235        235      235
# 2009      247  247       247              247       247        247      247
# 2010      251  251       251              251       251        251      251
# 2011      223  223       223              223       223        223      223
# 2012      215  215       215              215       215        215      215
# 2013      195  195       195              195       195        195      195
# 2014      177  177       177              177       177        177      177
# ...

# %%
year_labels = sorted(df["OCC_YEAR"].unique())
neighbourhood_labels = sorted(df["NEIGHBOURHOOD_158"].unique().tolist())
list1 = df['NEIGHBOURHOOD_158'].value_counts()

# %%
pl = df['NEIGHBOURHOOD_158'].value_counts().plot.bar(figsize=(40,10))

# %%
sns.scatterplot(data=df,x='NEIGHBOURHOOD_158', y='OCC_YEAR')
sns.set(rc={"figure.figsize":(20, 10)})

# %%
def remove_outliers(data, threshold=3):
    mean = np.mean(data)
    std = np.std(data)
    z_scores = [(x - mean) / std for x in data]
    filtered_data = [x for x, z in zip(data, z_scores) if abs(z) <= threshold]
    return filtered_data

filtered_data = remove_outliers(list1) #Not sure if this makes sense, can get rid of this
print(filtered_data)
# Out:
# [132, 117, 113, 112, 111, 109, 104, 103, 102, 98, 92, 90, 89, 89, 86, 85, 80, 79, 79, 78, 76, 76, 68, 66, 62, 57, 57, 57, 56, 56, 55, 53, 51, 51, 48, 47, 46, 44, 43, 43, 43, 42, 41, 40, 39, 39, 37, 37, 36, 35, 34, 34, 33, 33, 32, 32, 32, 31, 29, 28, 28, 28, 28, 27, 27, 27, 26, 26, 25, 24, 23, 23, 23, 22, 22, 21, 21, 21, 20, 20, 20, 19, 18, 17, 16, 16, 16, 16, 15, 15, 15, 15, 15, 15, 15, 14, 14, 14, 13, 12, 12, 12, 12, 12, 12, 11, 11, 11, 11, 11, 11, 11, 11, 9, 9, 9, 9, 9, 8, 8, 8, 8, 8, 8, 7, 7, 7, 7, 7, 6, 6, 6, 6, 6, 5, 5, 5, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3, 3, 3, 3, 2, 1, 1, 1]

# %%
df_pivot = pd.pivot_table(data=df, values ='OCC_YEAR', index =['NEIGHBOURHOOD_158','DEATH','INJURIES'],
                          aggfunc = max)

# %%
df_pivot
# Out:
#                                              OCC_YEAR
# NEIGHBOURHOOD_158            DEATH INJURIES
# Agincourt North              0     0             2020
#                                    1             2022
# Agincourt South-Malvern West 0     0             2022
#                                    1             2019
#                                    2             2012
# ...                                               ...
# Yorkdale-Glen Park           0     4             2019
#                              1     0             2022
#                                    1             2020
#                                    2             2014
#                              2     0             2018
#
# [682 rows x 1 columns]

# %%
df_groupby_neighbourhood = df.groupby('NEIGHBOURHOOD_158')

# %%
df_groupby_neighbourhood.max()
# Out:
#                                       X          Y  OBJECTID EVENT_UNIQUE_ID
# NEIGHBOURHOOD_158
# Agincourt North              -79.255514  43.813123      5598  GO-20221458014  \
# Agincourt South-Malvern West -79.238750  43.796536      5689   GO-2022933858
# Alderwood                    -79.526965  43.608862      5620    GO-202216903
# Annex                        -79.390196  43.674898      5628   GO-2022627272
# Avondale                     -79.403776  43.757768      4835  GO-20201568363
# ...                                 ...        ...       ...             ...
# Yonge-Doris                  -79.411989  43.779763      1799  GO-20114066404
# Yonge-Eglinton               -79.403318  43.704592      5656   GO-2022151149
# Yonge-St.Clair               -79.393774  43.694651      2945   GO-2016927444
# York University Heights      -79.465014  43.787288      5690   GO-2022749012
# Yorkdale-Glen Park           -79.442741  43.726800      5696   GO-2022668604
#
# ...

# %%
df.to_csv('Checkpoint1.csv')
